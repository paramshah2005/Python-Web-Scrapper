# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
website = 'https://ackodrive.com/collection/maruti-suzuki-cars/'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
res = soup.find_all('div',{'data-testid':'listingcardesktop'})
res
# Out:
# [<div class="styles__Wrapper-sc-ad1b3a08-0 iTGjuL" data-testid="listingcardesktop"><div class="styles__ModelSection-sc-ad1b3a08-1 cZBYsU"><div class="styles__ModelDetails-sc-a6403e05-0 edzyap"><div class="styles__BestsellerWrapper-sc-a6403e05-7 htBjOW" data-testid="best_seller"><svg class="styles__StyledBestSellerStarIcon-sc-ad1b3a08-7 bnpuUg" fill="none" height="13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M5.53 4.165 7 1.186l1.47 2.98c.15.302.438.511.772.56l3.287.477-2.379 2.32a1.025 1.025 0 0 0-.294.906l.561 3.274-2.94-1.545a1.025 1.025 0 0 0-.954 0l-2.94 1.545.561-3.274a1.025 1.025 0 0 0-.294-.907L1.47 5.203l3.288-.477c.334-.049.623-.258.772-.56Z" stroke="#fff" stroke-width="1.05"></path></svg>Bestseller</div><a class="styles__AnchorTagWithoutUnderline-sc-a6403e05-33 bXIogR" data-testid="car_model_brand_title" href="https://ackodrive.com/cars/maruti-suzuki-baleno/"><div class="styles__ModelStatusWrapper-sc-4db1e074-14 brdlRa"><h2 class="styles__ModelTitle-sc-a6403e0
# ...

# %%
len(res)
# Out:
# 16

# %%
res[0]
# Out:
# <div class="styles__Wrapper-sc-ad1b3a08-0 iTGjuL" data-testid="listingcardesktop"><div class="styles__ModelSection-sc-ad1b3a08-1 cZBYsU"><div class="styles__ModelDetails-sc-a6403e05-0 edzyap"><div class="styles__BestsellerWrapper-sc-a6403e05-7 htBjOW" data-testid="best_seller"><svg class="styles__StyledBestSellerStarIcon-sc-ad1b3a08-7 bnpuUg" fill="none" height="13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M5.53 4.165 7 1.186l1.47 2.98c.15.302.438.511.772.56l3.287.477-2.379 2.32a1.025 1.025 0 0 0-.294.906l.561 3.274-2.94-1.545a1.025 1.025 0 0 0-.954 0l-2.94 1.545.561-3.274a1.025 1.025 0 0 0-.294-.907L1.47 5.203l3.288-.477c.334-.049.623-.258.772-.56Z" stroke="#fff" stroke-width="1.05"></path></svg>Bestseller</div><a class="styles__AnchorTagWithoutUnderline-sc-a6403e05-33 bXIogR" data-testid="car_model_brand_title" href="https://ackodrive.com/cars/maruti-suzuki-baleno/"><div class="styles__ModelStatusWrapper-sc-4db1e074-14 brdlRa"><h2 class="styles__ModelTitle-sc-a6403e05
# ...

# %%
res[0].find('h2').get_text()
# Out:
# 'Maruti Suzuki Baleno'

# %%
res[0].find('p',{'data-testid':'car_variant_fuel_type'}).get_text()
# Out:
# 'Petrol'

# %%
res[0].find('div',{'class':'styles__CityName-sc-a6403e05-17 fZrHFu'}).get_text()
# Out:
# 'in Delhi'

# %%
res[0].find('div',{'class':'styles__Price-sc-a6403e05-18 bsWAfs'}).get_text()
# Out:
# '₹7.57 L'

# %%
res[0].find('p',{'class':'styles__ParaWithoutMargins-sc-a6403e05-34 iAPjDz','data-testid':None}).get_text()
# Out:
# 'Available in 6 colors'
